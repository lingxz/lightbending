# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-white')
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import plot_rs, ltb_graphs

# %%
from utils import plot_rs, ltb_graphs
# using output from curved.py
plot_rs('data/curvedpyoutput.csv', plot_ishak=True, plot_kantowski=True, latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %%
from utils import plot_rs_multiple_ks
# using output from curved.py
sns.set_theme()
plot_rs_multiple_ks('curvedpyoutput_withk.csv', latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific2/lib/python3.9/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# fixed M, varying hole size
from utils import plot_rs_multiple_ks
# using output from curved.py
plot_rs_multiple_ks('curvedpyoutput_withk2.csv', latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific3/lib/python3.9/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# fixed M, varying hole size
from utils import plot_rs_multiple_ks
# using output from curved.py
plot_rs_multiple_ks('data/curvedpyoutput_withk4.csv', latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific3/lib/python3.9/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# fixed M, varying hole size
from utils import plot_rs_multiple_ks
# using output from curved.py
plot_rs_multiple_ks('data/curvedpyoutput_withk5.csv', latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific3/lib/python3.9/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# fixed hole size rh, varying M
from utils import plot_rs_multiple_ks
plot_rs_multiple_ks('curvedpyoutput_fixedr_withk.csv', latex=False)
# Out:
# /home/lingxz/.conda/envs/scientific3/lib/python3.9/site-packages/IPython/core/pylabtools.py:132: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Generating Fig 8 and 9 in report

# %%
# using output from curved_const_rh.py
plot_rs('data/curved_const_rh_output.csv', plot_ishak=True, plot_kantowski=True, latex=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-b537b58ed251> in <module>
#       1 # using output from curved_const_rh.py
# ----> 2 plot_rs('data/curved_const_rh_output.csv', plot_ishak=True, plot_kantowski=True, latex=True)
#
# ~/projects/lightbending/utils.py in plot_rs(filename, plot_ishak, plot_kantowski, latex, filenames)
#     157     set_typography(latex)
#     158
# --> 159     df = pd.read_csv(filename)
#     160
#     161     numerical_res =[]
#
# ...

# %% [markdown]
# ## LTB pressure, mass, density graphs (Appendix A)

# %%
ltb_graphs()
# Out:
# D:\GIT\msciproject\utils.py:345: RuntimeWarning: invalid value encountered in log
#   return 4*np.pi*rho0*Rs**3*(np.log((Rs+r)/Rs) - r/(Rs+r))
# C:\Miniconda3\envs\scientific\lib\site-packages\matplotlib\figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
